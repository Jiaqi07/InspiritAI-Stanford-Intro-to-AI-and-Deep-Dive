# %%
#@title Run this to load some packages! { display-mode: "form" }
import random
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import cm
import gym
from IPython.display import HTML

import tqdm

ats = {1: "hit", 0:"stay"}

def play_blackjack(epsilon, print_steps=False):
  ### YOUR CODE HERE ###
  game = []
  state = blackjack.reset()
  game_over = False
  while game_over == False:
      if print_steps: 
        print("Your cards: ", blackjack.player)
        print_state(state)
      action = epsilon_greedy(state, epsilon)
      if print_steps: print(f"Agents chooses to {ats[action]}")
      next_state, reward, game_over, _ = blackjack.step(action)
      game.append((state, action))
      state = next_state
      if game_over:
        if print_steps:
          print("Your cards: ", blackjack.player)
          print_state(state)
          print("Game over!")
          print(f"Dealer has {blackjack.dealer}")
          print(rtm[reward])
        game.append(reward)    
  return game
  ### END CODE ###

def get_best_action(hand_val, dealer_card, usable_ace):
    state = (hand_val, dealer_card, usable_ace)

    # Compute Q(state, True)
    if num_games[(state,True)] == 0:
      Q_state_true = 0
    else:
      Q_state_true = sum_rewards[(state,True)] / num_games[(state,True)]
    
    # Compute Q(state, False)
    if num_games[(state,False)] == 0:
      Q_state_false = 0
    else:
      Q_state_false = sum_rewards[(state,False)] / num_games[(state,False)]

    return Q_state_true >= Q_state_false

def make_subplot(ax, usable_ace):
    x_coords = np.arange(1, 11) # dealer's cards
    y_coords = np.arange(11, 22) # gambler's hand values
    Z = np.array([[get_best_action(y, x, usable_ace) for x in x_coords] for y in y_coords])
    surf = ax.imshow(Z, cmap=plt.get_cmap('Set1', 2), extent=[0.5, 10.5, 21.5, 10.5])
    plt.xticks(x_coords)
    plt.yticks(y_coords)
    plt.gca().invert_yaxis()
    ax.set_xlabel('Dealer Showing')
    ax.set_ylabel('Player Sum')
    col1_patch = mpatches.Patch(color='darkgray', label='Hit')
    col2_patch = mpatches.Patch(color='red', label='Stick')
    plt.legend(handles=[col1_patch, col2_patch])

def plot_strategy():
  fig = plt.figure(figsize=(13, 13))
  ax = fig.add_subplot(121)
  ax.set_title('Usable Ace')
  make_subplot(ax, True)
  ax = fig.add_subplot(122)
  ax.set_title('No Usable Ace')
  make_subplot(ax, False)
  plt.show()

def best_action(state):
  ### YOUR CODE HERE ###
  # Compute Q(state, True)
  if num_games[(state,True)] == 0:
    Q_state_true = 0
  else:
    Q_state_true = sum_rewards[(state,True)] / num_games[(state,True)]
  
  # Compute Q(state, False)
  if num_games[(state,False)] == 0:
    Q_state_false = 0
  else:
    Q_state_false = sum_rewards[(state,False)] / num_games[(state,False)]

  return Q_state_true >= Q_state_false
  ### END CODE ###

def print_state(state):
  print()
  print("Hand value:", state[0])
  print("Dealer's card:", state[1])
  print("Useable ace?:", state[2])
  print("-----")

rtm = {0:"It's a tie!", -1: "You lose!", 1:"You win!"}
def play_human(blackjack):
  print()
  state = blackjack.reset()
  print("Your cards: ", blackjack.player)
  print("Hand value:", state[0])
  print("Dealer's card:", state[1])
  print("Useable ace?:", state[2])
  print("-----")

  while True:
    move = input('1 for hit 0 for stay: ') == '1'
    state, reward, game_over, _ = blackjack.step(move)
    print("Your cards: ", blackjack.player)
    print("Hand value:", state[0])
    print("Dealer's card:", state[1])
    print("Useable ace?:", state[2])
    print("-----")
    if game_over:
      print("Game over!")
      print(f"Dealer has {blackjack.dealer}")
      print(rtm[reward])
      break
  return reward

def play_n_times(blackjack, n):
  return np.mean([play_human(blackjack) for _ in range(n)])

sum_rewards = Counter()
num_games = Counter()

# %% [markdown]
# # Reinforcement Learning
# By now, might have heard of the term 'reinforcement learning'. Today, we'll see exactly what that means and apply it to the widely played game of blackjack! Reinforcement learning is all about training agents to make optimal decisions in certain states.
#
#
# **Here are some examples of what RL can do**.
#
#
# ![](https://lh3.googleusercontent.com/cTaZiZNod4_aZxSYzV-MuAzavS87y838E9Zp8BHrz65_DLi3cJCESl0sDO2ucRxLByeiJ9fQFx4kC8c-6wKivikliGgNFd7c7WIfKfQ=w1440)

# %%
#@title Run to see an example of a RL agent learning to play breakout!

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/V1eYniJ0Rnk" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/V1eYniJ0Rnk" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ![](https://www.thesprucepets.com/thmb/64ApN7vccbRhZ5mnwXLyYUjt5ig=/450x0/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-992416282-5c296bcdc9e77c00012eb55d.jpg)
#
# **Discuss:** How do you train a pet?
#
# ![](https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/beagle-with-treat-royalty-free-image-172977570-1559147501.jpg?crop=0.665xw:1.00xh;0.119xw,0&resize=640:*)
#
# We'll see how we can apply similar concepts to 'train' RL agents. **The techniques we'll talk about today drive technologies that allow computers to beat humans in chess, go, and videogames; autonomous driving; and robotic controls!**

# %% [markdown]
# # Blackjack
#
# ![](https://upload.wikimedia.org/wikipedia/commons/3/33/Blackjack21.jpg)
#
# To motivate our discussion, we'll use the game of blackjack. Though you can be sure that the odds are *always* against the gambler, certain play strategies are better than others. Despite Blackjack having been played since the 17th century, it was not until 1956 that a team of statisticians managed to find the provably optimal play strategy through a lengthy series of probability calculations!
#
# Just to make sure everyone knows how to play, here are the rules:
#
#
# * You and the dealer each start with two cards. You can see both of your cards and one of the dealer's cards
# * You decide to either "hit" or "stay"
# * "hit" means you draw another card
# * "stay" means you're done!
# * The goal is to make the sum of your cards higher than the dealers, but not higher than 21.
# * J, Q, K are each worth 10
# * A is worth either 1 or 11 (whichever gives you the highest sum without going over 21)
# * Dealer gets to pick cards after you're done
#
#
# Don't worry, we can play a couple of times to get the hang of it!

# %%
blackjack = gym.make('Blackjack-v0')

# %%
play_human(blackjack)
# Out:
# Your cards:  [2, 10]
# Hand value: 12
# Dealer's card: 6
# Useable ace?: False
# -----

# %% [markdown]
# # Defining the world
#
# In any reinforcement learning task we need to define the world in which the agent exists. There are 3 things we need to define:
#
# 1. **states**: Where am I?
# 2. **actions**: What can I do?
# 4. **rewards**: How good were my decisions?
#
# These interact together to define our world as follows!
#
# ![](https://dzone.com/storage/temp/6976061-screen-shot-2017-10-20-at-22200-pm.png)
#
# **Discuss**: What are the states, actions and rewards in the following?
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQcCByH1UFKkeo8d0ZkKilw9LiuaG5sPFzIYQ&usqp=CAU)
#
# ![](https://i1.wp.com/metro.co.uk/wp-content/uploads/2019/09/Mobile_MarioKartTour_01-3eb4.jpg?quality=90&strip=all&zoom=1&resize=644%2C664&ssl=1)
#
# ![](data:image/jpeg;base64,...)
#
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# In blackjack, we'll define a **state** using the following format:
#
# $s = $`(sum_of_cards_in_hand, dealers_card, useable_ace)`
#
# where:
#
# *   `sum_of_cards_in_hand` is sum of cards in hand (integer)
# *   `dealers_card` is the dealer's visible card (integer)
# *   `useable_ace` is whether or not we have a useable ace (boolean)
#
# The **actions** are to hit or to stay.
#
# Because we are interested in training our agent to win as much as possible, we'll define a simple **reward** function which is $+1$ upon winning, $-1$ upon losing, and $0$ at all intermediate (i.e. non-game-ending) states, as well as upon tieing. We might make several moves before we get get a non-zero reward!

# %% [markdown]
# # What are we trying to learn again?
#
# **Discuss**: Given this a world described by **states, actions**, and **rewards**. What are we trying to have our agent learn?
#
# Hint: Think of the agent as a hedonist. They are trying to rack up as much reward as possible!
#
#
# ![](https://dzone.com/storage/temp/6976061-screen-shot-2017-10-20-at-22200-pm.png)

# %% [markdown]
# # Policy
#
# We're trying to learn a **policy**: rules for how we'll select **actions** based on the **state** of the world. The objective is to learn a policy that gets us the largest **reward** possible!

# %% [markdown]
# # Value
#
# Let's define the **value** $Q(s, a)$ of an action $a$, at state $s$ as the expected future reward of taking an action at a certain state. Think $Q$ for quality: what payoff should we expect with this move?
#
# **Discuss:** if we have access to $Q$, what would be a good policy for the agent??
#
# We'll define a couple of simple worlds to test our function. Here are two examples:

# %%
q_traffic = {('red', 'go'):-1, ('green', 'go'):1, ("red", 'stop'):1, ('green', 'stop'):-0.5}
traffic_state = 'red'
actions_traffic = ['go', 'stop']

black_jack_state = 21
q_black_jack = {(21, 'hit'): -1, (21, 'stay'): 1} # this would have more... 
actions_black_jack = ['hit', 'stay']

# %% [markdown]
# **Question:** Explain what q_traffic is. Do the values make sense? How about q_black_jack?
#
# **Exercise:** Implement your policy! Your policy should return the best action given a state, the value function, and a list of possible actions!

# %%
def q_policy_implementation(s, q, actions):
  """
  s:       is the state
  q:       is a dictionary mapping tuples (s, a) to their value Q(s, a)
           i.e q[(s, a)] gets the value of (s, a).
  actions: is a list of possible action
  """
  """
  bestCase = None 
  best_value = None

  for data in q:
    state = data[0]
    action = data[1]
    val = q[data]

    if not bestCase and state == s:
      bestCase = {(state, action): val}
      best_value = val
    else:
      if val > best_value and state == s:
        bestCase = action
        best_value = val
  return bestCase
  """
  
  return max([(state, v, action) for (state, action), v in q.items() if state == s])[-1]
  
# ===== Read this to see what the test is doing! =======
assert(q_policy_implementation(traffic_state, q_traffic, actions_traffic) == 'stop' )
assert(q_policy_implementation(black_jack_state, q_black_jack, actions_black_jack) == 'stay')

print("All tests passed :)")
# Out:
# All tests passed :)

# %% [markdown]
# **Optional Exercise:** Make your own world by defining the value function, current state and possible actions to test if your function works!

# %%
## BEGIN CODE

## END CODE

# %% [markdown]
# Note that in real life we don't get a nice dictionary with our value function, so we'll have to learn it! This is the core idea behind our algorithm for today, which is called **Q-learning**. By experimenting with different actions, we'll learn what tends to happen when we make an action from a particular state.
#
#
# # Q-Learning - Estimating Value
#
# In order to learn $Q$, we'll repeat the following two steps:
# 1. Run an episode: have the agent interact with the world in some way (more on how later!)
# 2. Update the value, $Q(s, a)$, for each $(s, a)$ pair that occurred in the episode based on the rewards that we got!
#
# For blackjack this is:
# 1.   Play a game of Blackjack.
# 2.   Update the $Q(s,a)$ value, for each $(s,a)$ pair that occurred in the game, based on whether we won or lost at the end.

# %% [markdown]
# ## Updating the Value Estimates
#
# We can represent our game of blackjack like this:
#
# $s_1, a_1, s_2, a_2, \ldots, s_n, a_n, r$
#
# Where $r$ is the reward received at the end of the game: we're in a state, we take an action, repeat. Eventually, the game ends and we get a reward.
#
# One complication here is that Blackjack games last for a variable number of moves, so we don't know what $n$ is upfront!
#
# Suppose that, in code, this gameplay data is given you in the following form:
#
# `game = [(s_1,a_1), (s_2,a_2), ... , (s_n,a_n), r]`
#
# That is, `game` is a `List` of $n$ `Tuples` (each of which contains a state and an action) followed by a single reward at the end.

# %% [markdown]
# We'll keep a tally of the rewards we get for each action in each state, so that we can find the average value.
#
# **Exercise:** Write a function that takes a `game` as argument and updates `sum_rewards` and `num_games` appropriately.
# * `sum_rewards[(s, a)]` is the total reward at the state `(s, a)`.
# * `num_games[(s, a)]` is the number of times we've seen the state `(s, a)`.
#
# At the start, the two dictionaries are both initialized so that the value for each `(s, a)` pair is 0.

# %%
def update_counters(game):
  reward = game[-1]
  for state_action_tuple in game[:-1]: #tuple is (s,a)
    num_games[state_action_tuple] += 1
    sum_rewards[state_action_tuple] += reward

# %% [markdown]
# # Choosing Actions
#
# Now we've got a way to learn the value of each action from each state!
#
# But how do we use that to actually play the game while we're still learning? (What policy does the agent use while it is training?)
#
# **Discuss:** Evaluate the following strategies:
# * **Explore:** At any state, just randomly select an action!
# * **Exploit:** At any state, pick the action we currently think is the best based on our value estimate! (this is the q_policy_implementation that we wrote!)
#
# ![](https://asopa.typepad.com/.a/6a00d83454f2ec69e2022ad3b982a8200b-800wi)

# %% [markdown]
# ### Epsilon Greedy ($\varepsilon$-greedy) approach!
#
# There is a trade-off between the two strategies above, so we compromise and mix the two strategies together! We'll use something called the $\varepsilon$-greedy algorithm! This algorithm explores (selects a random action) with probability $\varepsilon$, and exploits (selects the best action) with probability $(1-\varepsilon)$.
#
# **Exercise:** Read the code below to see how this policy is implemented!

# %%
def epsilon_greedy(state, epsilon):
  action = best_action(state)
  # Return best_action with probability 1-epsilon
  if np.random.binomial(n=1,p=1-epsilon):
    return action
  
  # Otherwise, return random action
  else:
    return np.random.binomial(n=1,p=0.5)

# %%
np.random.binomial(n=1, p=0.5)
# Out:
# 1

# %% [markdown]
# # Training our Agent
#
# Time to put it all together and actually train our agent to learn a good blackjack strategy!
#
# We'll use the `play_blackjack(epsilon)` function which plays the game of blackjack using the epsilon_greedy policy, and then update our counters!

# %%
epsilon = 0.15
for iteration in tqdm.tqdm(range(1000000)):
  game = play_blackjack(epsilon)
  update_counters(game)
# Out:
# 100%|██████████| 1000000/1000000 [01:11<00:00, 13891.87it/s]

# %%
num_games
# Out:
# Counter({((4, 1, False), False): 57,
#          ((4, 1, False), True): 435,
#          ((4, 2, False), 0): 81,
#          ((4, 2, False), True): 390,
#          ((4, 3, False), False): 23,
#          ((4, 3, False), 1): 453,
#          ((4, 4, False), 0): 48,
#          ((4, 4, False), True): 410,
#          ((4, 5, False), 0): 50,
#          ((4, 5, False), 1): 408,
#          ((4, 6, False), False): 184,
#          ((4, 6, False), True): 263,
#          ((4, 7, False), False): 28,
#          ((4, 7, False), True): 392,
#          ((4, 8, False), False): 40,
#          ((4, 8, False), True): 436,
#          ((4, 9, False), False): 50,
#          ((4, 9, False), True): 407,
#          ((4, 10, False), False): 144,
#          ((4, 10, False), True): 1626,
#          ((5, 1, False), False): 113,
#          ((5, 1, False), True): 766,
#          ((5, 2, False), False): 88,
#          ((5, 2, False), True): 819,
#          ((5, 3, False), 0): 160,
#          ((5, 3, False), True): 728,
#          ((5, 4, False), False): 481,
#          ((5, 4, False), True): 495,
#          ((5, 5, False), False): 78,
#          ((5, 5, False), True): 879,
#          ((5, 6, False), False): 800,
#          ((5, 6, False), True): 70,
#          ((5, 7, False), 0): 70,
#          ((5, 7, False), True): 835,
#          ((5, 8, False), False): 79,
#          ((5, 8, False), True): 840,
#          ((5, 9, False), False): 693,
#          ((5, 9, False), True): 247,
#          ((5, 10, False), 0): 1197,
#          ((5, 10, False), True): 2572,
#          ((6, 1, False), False): 112,
#          ((6, 1, False), True): 1240,
#          ((6, 2, False), False): 114,
#          ((6, 2, False), 1): 1252,
#          ((6, 3, False), 0): 1209,
#          ((6, 3, False), True): 121,
#          ((6, 4, False), False): 118,
#          ((6, 4, False), True): 1320,
#          ((6, 5, False), False): 114,
#          ((6, 5, False), True): 1314,
#          ((6, 6, False), False): 116,
#          ((6, 6, False), 1): 1327,
#          ((6, 7, False), 0): 108,
#          ((6, 7, False), True): 1259,
#          ((6, 8, False), False): 114,
#          ((6, 8, False), True): 1194,
#          ((6, 9, False), False): 111,
#          ((6, 9, False), 1): 1272,
#          ((6, 10, False), 0): 411,
#          ((6, 10, False), True): 5171,
#          ((7, 1, False), False): 146,
#          ((7, 1, False), True): 1811,
#          ((7, 2, False), 0): 163,
#          ((7, 2, False), True): 1832,
#          ((7, 3, False), False): 148,
#          ((7, 3, False), True): 1748,
#          ((7, 4, False), False): 835,
#          ((7, 4, False), True): 1107,
#          ((7, 5, False), 0): 149,
#          ((7, 5, False), True): 1764,
#          ((7, 6, False), False): 189,
#          ((7, 6, False), True): 1694,
#          ((7, 7, False), 0): 178,
#          ((7, 7, False), True): 1772,
#          ((7, 8, False), 0): 147,
#          ((7, 8, False), True): 1762,
#          ((7, 9, False), False): 157,
#          ((7, 9, False), True): 1660,
#          ((7, 10, False), False): 774,
#          ((7, 10, False), True): 6796,
#          ((8, 1, False), False): 184,
#          ((8, 1, False), True): 2304,
#          ((8, 2, False), False): 233,
#          ((8, 2, False), True): 2208,
#          ((8, 3, False), 0): 188,
#          ((8, 3, False), True): 2189,
#          ((8, 4, False), False): 221,
#          ((8, 4, False), True): 2302,
#          ((8, 5, False), False): 180,
#          ((8, 5, False), 1): 2293,
#          ((8, 6, False), False): 173,
#          ((8, 6, False), True): 2293,
#          ((8, 7, False), False): 203,
#          ((8, 7, False), True): 2256,
#          ((8, 8, False), False): 178,
#          ((8, 8, False), True): 2357,
#          ((8, 9, False), False): 194,
#          ((8, 9, False), True): 2232,
#          ((8, 10, False), 0): 681,
#          ((8, 10, False), True): 9242,
#          ((9, 1, False), False): 237,
#          ((9, 1, False), True): 2800,
#          ((9, 2, False), False): 221,
#          ((9, 2, False), True): 2902,
#          ((9, 3, False), False): 238,
#          ((9, 3, False), True): 2753,
#          ((9, 4, False), 0): 245,
#          ((9, 4, False), True): 2777,
#          ((9, 5, False), False): 230,
#          ((9, 5, False), True): 2843,
#          ((9, 6, False), False): 395,
#          ((9, 6, False), True): 2671,
#          ((9, 7, False), False): 214,
#          ((9, 7, False), True): 2767,
#          ((9, 8, False), 0): 305,
#          ((9, 8, False), True): 2757,
#          ((9, 9, False), 0): 484,
#          ((9, 9, False), True): 2473,
#          ((9, 10, False), False): 947,
#          ((9, 10, False), True): 11332,
#          ((10, 1, False), False): 285,
#          ((10, 1, False), True): 3391,
#          ((10, 2, False), 0): 348,
#          ((10, 2, False), True): 3298,
#          ((10, 3, False), 0): 258,
#          ((10, 3, False), True): 3337,
#          ((10, 4, False), 0): 497,
#          ((10, 4, False), True): 3031,
#          ((10, 5, False), False): 295,
#          ((10, 5, False), True): 3463,
#          ((10, 6, False), 0): 256,
#          ((10, 6, False), 1): 3308,
#          ((10, 7, False), 0): 285,
#          ((10, 7, False), True): 3404,
#          ((10, 8, False), 0): 295,
#          ((10, 8, False), True): 3418,
#          ((10, 9, False), False): 243,
#          ((10, 9, False), True): 3407,
#          ((10, 10, False), False): 1093,
#          ((10, 10, False), True): 13627,
#          ((11, 1, False), False): 321,
#          ((11, 1, False), True): 4042,
#          ((11, 2, False), 0): 333,
#          ((11, 2, False), True): 4096,
#          ((11, 3, False), 0): 291,
#          ((11, 3, False), True): 3930,
#          ((11, 4, False), 0): 346,
#          ((11, 4, False), True): 3961,
#          ((11, 5, False), 0): 337,
#          ((11, 5, False), 1): 4104,
#          ((11, 6, False), False): 317,
#          ((11, 6, False), 1): 3930,
#          ((11, 7, False), 0): 319,
#          ((11, 7, False), 1): 4049,
#          ((11, 8, False), False): 354,
#          ((11, 8, False), True): 3980,
#          ((11, 9, False), False): 306,
#          ((11, 9, False), True): 4011,
#          ((11, 10, False), False): 1323,
#          ((11, 10, False), True): 16252,
#          ((12, 1, False), False): 677,
#          ((12, 1, False), True): 7990,
#          ((12, 1, True), 0): 40,
#          ((12, 1, True), True): 432,
#          ((12, 2, False), False): 1855,
#          ((12, 2, False), True): 6870,
#          ((12, 2, True), False): 46,
#          ((12, 2, True), True): 395,
#          ((12, 3, False), 0): 7765,
#          ((12, 3, False), True): 615,
#          ((12, 3, True), False): 197,
#          ((12, 3, True), 1): 284,
#          ((12, 4, False), False): 8004,
#          ((12, 4, False), True): 697,
#          ((12, 4, True), 0): 26,
#          ((12, 4, True), True): 438,
#          ((12, 5, False), 0): 8002,
#          ((12, 5, False), True): 645,
#          ((12, 5, True), False): 37,
#          ((12, 5, True), True): 445,
#          ((12, 6, False), False): 5484,
#          ((12, 6, False), True): 2879,
#          ((12, 6, True), 0): 36,
#          ((12, 6, True), 1): 389,
#          ((12, 7, False), False): 667,
#          ((12, 7, False), True): 7905,
#          ((12, 7, True), 0): 32,
#          ((12, 7, True), 1): 415,
#          ((12, 8, False), 0): 612,
#          ((12, 8, False), True): 7936,
#          ((12, 8, True), False): 37,
#          ((12, 8, True), True): 399,
#          ((12, 9, False), False): 627,
#          ((12, 9, False), True): 8113,
#          ((12, 9, True), False): 39,
#          ((12, 9, True), True): 394,
#          ((12, 10, False), 0): 2673,
#          ((12, 10, False), True): 31956,
#          ((12, 10, True), 0): 131,
#          ((12, 10, True), True): 1696,
#          ((13, 1, False), 0): 617,
#          ((13, 1, False), True): 8357,
#          ((13, 1, True), False): 70,
#          ((13, 1, True), True): 884,
#          ((13, 2, False), False): 6390,
#          ((13, 2, False), True): 2446,
#          ((13, 2, True), 0): 108,
#          ((13, 2, True), True): 813,
#          ((13, 3, False), False): 7640,
#          ((13, 3, False), True): 619,
#          ((13, 3, True), False): 81,
#          ((13, 3, True), True): 900,
#          ((13, 4, False), 0): 7187,
#          ((13, 4, False), True): 854,
#          ((13, 4, True), 0): 374,
#          ((13, 4, True), True): 554,
#          ((13, 5, False), False): 7774,
#          ((13, 5, False), True): 580,
#          ((13, 5, True), 0): 66,
#          ((13, 5, True), True): 829,
#          ((13, 6, False), False): 7656,
#          ((13, 6, False), True): 707,
#          ((13, 6, True), 0): 70,
#          ((13, 6, True), True): 882,
#          ((13, 7, False), False): 1043,
#          ((13, 7, False), True): 7963,
#          ((13, 7, True), False): 185,
#          ((13, 7, True), True): 835,
#          ((13, 8, False), False): 684,
#          ((13, 8, False), True): 8205,
#          ((13, 8, True), False): 115,
#          ((13, 8, True), True): 816,
#          ((13, 9, False), False): 708,
#          ((13, 9, False), True): 8072,
#          ((13, 9, True), False): 64,
#          ((13, 9, True), True): 903,
#          ((13, 10, False), False): 3622,
#          ((13, 10, False), True): 32151,
#          ((13, 10, True), False): 302,
#          ((13, 10, True), True): 3537,
#          ((14, 1, False), False): 704,
#          ((14, 1, False), True): 8495,
#          ((14, 1, True), False): 96,
#          ((14, 1, True), 1): 936,
#          ((14, 2, False), False): 7988,
#          ((14, 2, False), True): 620,
#          ((14, 2, True), False): 80,
#          ((14, 2, True), 1): 936,
#          ((14, 3, False), False): 7325,
#          ((14, 3, False), True): 612,
#          ((14, 3, True), False): 93,
#          ((14, 3, True), 1): 896,
#          ((14, 4, False), False): 7241,
#          ((14, 4, False), True): 695,
#          ((14, 4, True), 0): 74,
#          ((14, 4, True), 1): 924,
#          ((14, 5, False), False): 7266,
#          ((14, 5, False), True): 556,
#          ((14, 5, True), False): 226,
#          ((14, 5, True), True): 769,
#          ((14, 6, False), False): 7425,
#          ((14, 6, False), True): 719,
#          ((14, 6, True), 0): 81,
#          ((14, 6, True), True): 978,
#          ((14, 7, False), False): 718,
#          ((14, 7, False), True): 8393,
#          ((14, 7, True), False): 78,
#          ((14, 7, True), True): 921,
#          ((14, 8, False), 0): 798,
#          ((14, 8, False), True): 8358,
#          ((14, 8, True), False): 73,
#          ((14, 8, True), True): 938,
#          ((14, 9, False), False): 664,
#          ((14, 9, False), True): 8321,
#          ((14, 9, True), False): 85,
#          ((14, 9, True), True): 955,
#          ((14, 10, False), False): 2751,
#          ((14, 10, False), True): 33746,
#          ((14, 10, True), False): 321,
#          ((14, 10, True), True): 3783,
#          ((15, 1, False), False): 703,
#          ((15, 1, False), True): 8631,
#          ((15, 1, True), False): 94,
#          ((15, 1, True), True): 1079,
#          ((15, 2, False), False): 6917,
#          ((15, 2, False), True): 1309,
#          ((15, 2, True), 0): 79,
#          ((15, 2, True), True): 1049,
#          ((15, 3, False), False): 6891,
#          ((15, 3, False), True): 577,
#          ((15, 3, True), False): 309,
#          ((15, 3, True), True): 839,
#          ((15, 4, False), False): 6880,
#          ((15, 4, False), True): 575,
#          ((15, 4, True), False): 87,
#          ((15, 4, True), True): 995,
#          ((15, 5, False), False): 6985,
#          ((15, 5, False), True): 554,
#          ((15, 5, True), 0): 214,
#          ((15, 5, True), True): 895,
#          ((15, 6, False), False): 6922,
#          ((15, 6, False), 1): 593,
#          ((15, 6, True), False): 70,
#          ((15, 6, True), True): 1024,
#          ((15, 7, False), False): 710,
#          ((15, 7, False), True): 8646,
#          ((15, 7, True), False): 93,
#          ((15, 7, True), 1): 954,
#          ((15, 8, False), False): 6564,
#          ((15, 8, False), True): 2875,
#          ((15, 8, True), False): 83,
#          ((15, 8, True), True): 1005,
#          ((15, 9, False), False): 1101,
#          ((15, 9, False), True): 8101,
#          ((15, 9, True), 0): 96,
#          ((15, 9, True), True): 995,
#          ((15, 10, False), False): 3121,
#          ((15, 10, False), True): 34360,
#          ((15, 10, True), False): 340,
#          ((15, 10, True), 1): 4224,
#          ((16, 1, False), False): 741,
#          ((16, 1, False), 1): 8701,
#          ((16, 1, True), False): 441,
#          ((16, 1, True), 1): 767,
#          ((16, 2, False), False): 7430,
#          ((16, 2, False), True): 603,
#          ((16, 2, True), False): 88,
#          ((16, 2, True), True): 1195,
#          ((16, 3, False), False): 6315,
#          ((16, 3, False), True): 507,
#          ((16, 3, True), False): 180,
#          ((16, 3, True), 1): 1035,
#          ((16, 4, False), False): 6541,
#          ((16, 4, False), True): 560,
#          ((16, 4, True), False): 90,
#          ((16, 4, True), True): 1076,
#          ((16, 5, False), 0): 6645,
#          ((16, 5, False), True): 518,
#          ((16, 5, True), False): 111,
#          ((16, 5, True), True): 1130,
#          ((16, 6, False), False): 6845,
#          ((16, 6, False), True): 543,
#          ((16, 6, True), 0): 94,
#          ((16, 6, True), True): 1086,
#          ((16, 7, False), False): 859,
#          ((16, 7, False), 1): 8760,
#          ((16, 7, True), 0): 72,
#          ((16, 7, True), True): 1156,
#          ((16, 8, False), False): 8310,
#          ((16, 8, False), True): 700,
#          ((16, 8, True), False): 200,
#          ((16, 8, True), True): 999,
#          ((16, 9, False), False): 1654,
#          ((16, 9, False), True): 7729,
#          ((16, 9, True), False): 203,
#          ((16, 9, True), True): 975,
#          ((16, 10, False), False): 34820,
#          ((16, 10, False), True): 2996,
#          ((16, 10, True), False): 346,
#          ((16, 10, True), True): 4393,
#          ((17, 1, False), False): 8937,
#          ((17, 1, False), True): 771,
#          ((17, 1, True), False): 324,
#          ((17, 1, True), True): 1025,
#          ((17, 2, False), False): 6938,
#          ((17, 2, False), True): 620,
#          ((17, 2, True), False): 159,
#          ((17, 2, True), True): 1191,
#          ((17, 3, False), False): 6223,
#          ((17, 3, False), True): 523,
#          ((17, 3, True), 0): 99,
#          ((17, 3, True), True): 1177,
#          ((17, 4, False), False): 6091,
#          ((17, 4, False), True): 482,
#          ((17, 4, True), 0): 108,
#          ((17, 4, True), True): 1290,
#          ((17, 5, False), 0): 6209,
#          ((17, 5, False), True): 538,
#          ((17, 5, True), False): 173,
#          ((17, 5, True), True): 1198,
#          ((17, 6, False), 0): 6117,
#          ((17, 6, False), True): 601,
#          ((17, 6, True), 0): 128,
#          ((17, 6, True), 1): 1243,
#          ((17, 7, False), False): 8893,
#          ((17, 7, False), True): 712,
#          ((17, 7, True), False): 112,
#          ((17, 7, True), True): 1259,
#          ((17, 8, False), False): 7962,
#          ((17, 8, False), True): 642,
#          ((17, 8, True), False): 111,
#          ((17, 8, True), True): 1211,
#          ((17, 9, False), False): 8187,
#          ((17, 9, False), True): 1571,
#          ((17, 9, True), False): 108,
#          ((17, 9, True), True): 1148,
#          ((17, 10, False), False): 33268,
#          ((17, 10, False), True): 2723,
#          ((17, 10, True), False): 392,
#          ((17, 10, True), True): 4944,
#          ((18, 1, False), 0): 8658,
#          ((18, 1, False), True): 730,
#          ((18, 1, True), False): 166,
#          ((18, 1, True), True): 1252,
#          ((18, 2, False), False): 6328,
#          ((18, 2, False), True): 507,
#          ((18, 2, True), 0): 387,
#          ((18, 2, True), True): 1069,
#          ((18, 3, False), False): 5411,
#          ((18, 3, False), True): 459,
#          ((18, 3, True), False): 1365,
#          ((18, 3, True), True): 98,
#          ((18, 4, False), False): 5465,
#          ((18, 4, False), True): 473,
#          ((18, 4, True), 0): 1141,
#          ((18, 4, True), True): 258,
#          ((18, 5, False), False): 5503,
#          ((18, 5, False), True): 475,
#          ((18, 5, True), False): 1268,
#          ((18, 5, True), True): 103,
#          ((18, 6, False), False): 5551,
#          ((18, 6, False), True): 487,
#          ((18, 6, True), 0): 1396,
#          ((18, 6, True), True): 122,
#          ((18, 7, False), False): 8201,
#          ((18, 7, False), True): 673,
#          ((18, 7, True), 0): 1412,
#          ((18, 7, True), 1): 118,
#          ((18, 8, False), False): 7340,
#          ((18, 8, False), True): 610,
#          ((18, 8, True), False): 1356,
#          ((18, 8, True), True): 110,
#          ((18, 9, False), False): 8391,
#          ((18, 9, False), True): 646,
#          ((18, 9, True), False): 1261,
#          ((18, 9, True), True): 176,
#          ((18, 10, False), False): 30837,
#          ((18, 10, False), True): 2500,
#          ((18, 10, True), False): 5512,
#          ((18, 10, True), True): 392,
#          ((19, 1, False), 0): 7735,
#          ((19, 1, False), True): 640,
#          ((19, 1, True), False): 1399,
#          ((19, 1, True), True): 144,
#          ((19, 2, False), False): 5668,
#          ((19, 2, False), True): 470,
#          ((19, 2, True), False): 1497,
#          ((19, 2, True), True): 122,
#          ((19, 3, False), False): 5017,
#          ((19, 3, False), 1): 412,
#          ((19, 3, True), False): 1240,
#          ((19, 3, True), True): 154,
#          ((19, 4, False), False): 4975,
#          ((19, 4, False), True): 412,
#          ((19, 4, True), 0): 1399,
#          ((19, 4, True), 1): 139,
#          ((19, 5, False), 0): 4907,
#          ((19, 5, False), True): 450,
#          ((19, 5, True), False): 1458,
#          ((19, 5, True), True): 101,
#          ((19, 6, False), 0): 5143,
#          ((19, 6, False), True): 418,
#          ((19, 6, True), False): 1483,
#          ((19, 6, True), True): 131,
#          ((19, 7, False), False): 7812,
#          ((19, 7, False), True): 611,
#          ((19, 7, True), False): 1392,
#          ((19, 7, True), True): 123,
#          ((19, 8, False), False): 6830,
#          ((19, 8, False), True): 579,
#          ((19, 8, True), False): 1331,
#          ((19, 8, True), True): 114,
#          ((19, 9, False), 0): 7611,
#          ((19, 9, False), 1): 631,
#          ((19, 9, True), False): 1385,
#          ((19, 9, True), True): 112,
#          ((19, 10, False), False): 29086,
#          ((19, 10, False), True): 2285,
#          ((19, 10, True), False): 5503,
#          ((19, 10, True), True): 515,
#          ((20, 1, False), 0): 10967,
#          ((20, 1, False), True): 877,
#          ((20, 1, True), False): 1512,
#          ((20, 1, True), 1): 133,
#          ((20, 2, False), 0): 9007,
#          ((20, 2, False), True): 706,
#          ((20, 2, True), False): 1453,
#          ((20, 2, True), True): 123,
#          ((20, 3, False), False): 8325,
#          ((20, 3, False), True): 650,
#          ((20, 3, True), False): 1453,
#          ((20, 3, True), True): 107,
#          ((20, 4, False), False): 8239,
#          ((20, 4, False), True): 623,
#          ((20, 4, True), 0): 1402,
#          ((20, 4, True), True): 127,
#          ((20, 5, False), 0): 8269,
#          ((20, 5, False), True): 676,
#          ((20, 5, True), 0): 1564,
#          ((20, 5, True), 1): 132,
#          ((20, 6, False), False): 8489,
#          ((20, 6, False), 1): 666,
#          ((20, 6, True), False): 1469,
#          ((20, 6, True), True): 131,
#          ((20, 7, False), False): 10956,
#          ((20, 7, False), 1): 933,
#          ((20, 7, True), 0): 1458,
#          ((20, 7, True), True): 142,
#          ((20, 8, False), False): 10208,
#          ((20, 8, False), True): 850,
#          ((20, 8, True), False): 1340,
#          ((20, 8, True), True): 106,
#          ((20, 9, False), False): 11322,
#          ((20, 9, False), True): 940,
#          ((20, 9, True), False): 1426,
#          ((20, 9, True), True): 125,
#          ((20, 10, False), False): 42470,
#          ((20, 10, False), True): 3441,
#          ((20, 10, True), False): 5938,
#          ((20, 10, True), True): 506,
#          ((21, 1, False), 0): 4456,
#          ((21, 1, False), 1): 357,
#          ((21, 1, True), False): 4069,
#          ((21, 1, True), True): 323,
#          ((21, 2, False), False): 2346,
#          ((21, 2, False), True): 187,
#          ((21, 2, True), 0): 4036,
#          ((21, 2, True), True): 352,
#          ((21, 3, False), False): 1559,
#          ((21, 3, False), True): 132,
#          ((21, 3, True), False): 3857,
#          ((21, 3, True), True): 338,
#          ((21, 4, False), False): 1575,
#          ((21, 4, False), True): 135,
#          ((21, 4, True), 0): 4043,
#          ((21, 4, True), 1): 312,
#          ((21, 5, False), False): 1616,
#          ((21, 5, False), True): 133,
#          ((21, 5, True), False): 3935,
#          ((21, 5, True), True): 299,
#          ((21, 6, False), 0): 1803,
#          ((21, 6, False), True): 141,
#          ((21, 6, True), 0): 3971,
#          ((21, 6, True), True): 316,
#          ((21, 7, False), 0): 4494,
#          ((21, 7, False), True): 341,
#          ((21, 7, True), 0): 4002,
#          ((21, 7, True), True): 329,
#          ((21, 8, False), False): 3410,
#          ((21, 8, False), True): 270,
#          ((21, 8, True), 0): 4061,
#          ((21, 8, True), True): 331,
#          ((21, 9, False), False): 4381,
#          ((21, 9, False), True): 357,
#          ((21, 9, True), False): 4055,
#          ((21, 9, True), True): 318,
#          ((21, 10, False), False): 15464,
#          ((21, 10, False), True): 1231,
#          ((21, 10, True), 0): 16224,
#          ((21, 10, True), 1): 1267})

# %% [markdown]
# # Testing it out!
# When it's done training, let's put it to the test and play some real games!
# ![](https://www.johnchow.com/wp-content/uploads/2012/03/lots-of-money.jpeg)
#
# **Question:** Why is epsilon = 0 below?

# %%
play_blackjack(epsilon=0, print_steps=True)
# Out:
# Your cards:  [6, 5]
#
# Hand value: 11
# Dealer's card: 10
# Useable ace?: False
# -----
# Agents chooses to hit
# Your cards:  [6, 5, 4]
#
# Hand value: 15
# Dealer's card: 10
# Useable ace?: False
# -----
# Agents chooses to hit
# Your cards:  [6, 5, 4, 10]
#
# Hand value: 25
# Dealer's card: 10
# Useable ace?: False
# -----
# Game over!
# Dealer has [10, 10]
# You lose!
# [((11, 10, False), True), ((15, 10, False), True), -1.0]

# %% [markdown]
# # Strategy Visualization
#
# Let's take a look at the strategy our agent has learned! We've written a function called `plot_strategy()` that will do the visualization for you; give it a try!

# %%
plot_strategy()

# %% [markdown]
# Compare the strategy that your agent learned to the optimal Blackjack strategy, shown below on the left. It should look pretty similar!
#
# (Notice that the grid layouts differ a bit between our visualization and the one below; we plot the best actions aligned with the tick marks, whereas the following figure plots the best actions in between tick marks).
#
#
# ![alt text](https://ankonzoid.github.io/LearningX/classical_RL/blackjack/images/coverart.png)

# %% [markdown]
# # Optional: Questions to ponder
# * We kept $\varepsilon$, our exploration probability, at a constant $0.15$. If you could change the exploration probability throughout the training (and you definitely can!), how would you? Why?
# * We initialized our value estimates at $0$ for each state/action pair. How would our training behave differently if we initialized them to all $10$?
# * How big is our table for storing the values in terms of $n_s$, the number of possible states, and $n_a$ the number of possible actions?
# * If our states are images (think for example in robotics/self driving car applications which use cameras to model state), which have size say 128x128x3 pixels, each pixel taking a value from 0-255. What is $n_s$, the number of possible states?
# * Given the above discussion, what is one fatal flaw for the $Q$-learning algorithm, and how might you address it?

# %%
# Out:
# 12533760

# %%
# Out:
# 118287
